# %%
#2.3.1. 标量
#实例化两个标量，并使用它们执行一些熟悉的算术运算，即加法，乘法，除法和指数
import torch

x = torch.tensor([3.0])
y = torch.tensor([2.0])

x + y, x * y, x / y, x**y

# %%
#2.3.2. 向量
#通过一维张量处理向量。一般来说，张量可以具有任意长度，取决于机器的内存限制。
x = torch.arange(4)
x
#通过张量的索引来访问任一元素。
x[3]

# %%
#2.3.2.1. 长度、维度和形状
#通过调用 Python 的内置 len() 函数来访问张量的长度
len(x)
#通过 .shape 属性访问向量的长度。形状（shape）是一个元组，列出了张量沿每个轴的长度（维数）
x.shape

# %%
#2.3.3. 矩阵
#通过指定两个分量 m  和  n 来创建一个形状为 m×n  的矩阵
A = torch.arange(20).reshape(5, 4)
A
#在代码中访问矩阵的转置
A.T
#方矩阵的一种特殊类型，对称矩阵（symmetric matrix）  A  等于其转置： A=A⊤ 。这里我们定义一个对称矩阵 B：
B = torch.tensor([[1, 2, 3], [2, 0, 4], [3, 4, 5]])
B
#将 B 与它的转置进行比较
B == B.T

# %%
#2.3.4. 张量
X = torch.arange(24).reshape(2, 3, 4)
X

# %%
#2.3.5. 张量算法的基本性质
#将两个相同形状的矩阵相加会在这两个矩阵上执行元素加法
A = torch.arange(20, dtype=torch.float32).reshape(5, 4)
B = A.clone()  # 通过分配新内存，将A的一个副本分配给B
A, A + B
#
A * B
#将张量乘以或加上一个标量不会改变张量的形状，其中张量的每个元素都将与标量相加或相乘
a = 2
X = torch.arange(24).reshape(2, 3, 4)
a + X, (a * X).shape

# %%
#2.3.6. 汇总
#可以调用计算求和的函数
x = torch.arange(4, dtype=torch.float32)
x, x.sum()

# %%
#2.3.7. 点积（Dot Product）
y = torch.ones(4, dtype=torch.float32)
x, y, torch.dot(x, y)
#可以通过执行按元素乘法，然后进行求和来表示两个向量的点积
torch.sum(x * y)

# %%
#2.3.8. 矩阵-向量积
B = torch.ones(4, 3)
torch.mm(A, B)

# %%
#2.3.10. 范数
#L2范数中常常省略下标2，也就是说， ∥x∥等同于∥x∥2 。在代码中，我们可以按如下方式计算向量的L2范数
u = torch.tensor([3.0, -4.0])
torch.norm(u)
#与  L2  范数相比， L1  范数受异常值的影响较小。为了计算  L1  范数，我们将绝对值函数和按元素求和组合起来
torch.abs(u).sum()
